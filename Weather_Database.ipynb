# %%
# Challenge Part 1: Get weather description and precipitation for each city

#Import dependencies
from citipy import citipy
import numpy as np
import pandas as pd

# %%
# Create a random set of latitudes and longitudes (lats, lngs)
lats = np.random.uniform(low = -90.000, high = 90.000, size=1500)
lngs = np.random.uniform(low = -180.000, high = 180.000, size=1500)
lats_lngs = zip(lats, lngs)

# Store the tuple lats_lngs into a list
coordinates = list(lats_lngs)

# Initialize empty list to store city names
cities = []

# Use city.nearest_city to get the name of the nearest city for each latitude and longitude
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # Check that the city name unique, if true add it to the cities list
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 617

# %%
# Import requests, datetime, weather_api_key
import requests
from datetime import datetime
from config import weather_api_key

# %%
# Create base url for request
url = f'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}'

# %%
# Initialize list to store city weather data
city_data = []

# Print beginning of logging
print('Begging Data Retrieval     ')
print('---------------------------')

# Create counters
record_count = 1
set_count = 1


# Loop through all cities in cities list
for i, city in enumerate(cities):
    # Group cities in sets of 50
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    # Create endpoint url
    city_url = url + "&q=" + city.replace(" ","+")
 
    
    # Log the record number, set number, and city
    print(f'Recording {record_count} of {set_count}|{city}')
    record_count += 1
    
    # Run API request for each city
    try:
        # Parse the JSON and retrieve the data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        # try to get the rainfall and snowfall in the last hour, insert 0 if none
        try:
            city_rain = city_weather["rain"]["1h"]
        except KeyError:
            city_rain = 0
            
        try:
            city_snow = city_weather["snow"]["1h"]
        except KeyError:
            city_snow = 0
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information as a dictionary into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_weather_description,
                          "Rain (inches)": city_rain,
                          "Snow (inches)": city_snow})          

        # Skip city on any error
    except:
        print('City not found, skipping...')
        pass
        
# Print completion statement
print('----------------------------')
print('Data Retrieval Complete     ')
print('----------------------------')
len(city_data)
# Out:
# Begging Data Retrieval
# ---------------------------
# Recording 1 of 1|antalaha
# Recording 2 of 1|hilo
# Recording 3 of 1|ribeira grande
# Recording 4 of 1|cherskiy
# Recording 5 of 1|amderma
# City not found, skipping...
# Recording 6 of 1|mataura
# Recording 7 of 1|east london
# Recording 8 of 1|port alfred
# Recording 9 of 1|alice springs
# Recording 10 of 1|kapaa
# Recording 11 of 1|odweyne
# Recording 12 of 1|seddon
# Recording 13 of 1|nieuwpoort
# Recording 14 of 1|brainerd
# Recording 15 of 1|thompson
# Recording 16 of 1|hobart
# Recording 17 of 1|melfi
# Recording 18 of 1|urumqi
# Recording 19 of 1|yellowknife
# Recording 20 of 1|victoria
# Recording 21 of 1|trairi
# Recording 22 of 1|qaanaaq
# Recording 23 of 1|alofi
# Recording 24 of 1|bacuit
# City not found, skipping...
# Recording 25 of 1|sinkat
# City not found, skipping...
# Recording 26 of 1|bredasdorp
# Recording 27 of 1|rikitea
# Recording 28 of 1|chokurdakh
# Recording 29 of 1|richards bay
# Recording 30 of 1|evensk
# Recording 31 of 1|atbasar
# Recording 32 of 1|buala
# Recording 33 of 1|sentyabrskiy
# City not found, skipping...
# Recording 34 of 1|attawapiskat
# City not found, skipping...
# Recording 35 of 1|atuona
# Recording 36 of 1|pouembout
# Recording 37 of 1|punta arenas
# Recording 38 of 1|tabiauea
# City not found, skipping...
# Recording 39 of 1|xining
# Recording 40 of 1|barentsburg
# City not found, skipping...
# Recording 41 of 1|jamestown
# Recording 42 of 1|bluff
# Recording 43 of 1|kodiak
# Recording 44 of 1|puerto ayora
# Recording 45 of 1|uglovskoye
# Recording 46 of 1|kirakira
# Recording 47 of 1|taolanaro
# City not found, skipping...
# Recording 48 of 1|olafsvik
# Recording 49 of 1|lucapa
# Recording 50 of 1|garowe
# Recording 1 of 2|rio claro
# Recording 2 of 2|ushuaia
# Recording 3 of 2|bairiki
# Recording 4 of 2|hermanus
# Recording 5 of 2|tiksi
# Recording 6 of 2|bakchar
# Recording 7 of 2|monroe
# Recording 8 of 2|bengkulu
# Recording 9 of 2|ancud
# Recording 10 of 2|busselton
# Recording 11 of 2|lucea
# Recording 12 of 2|katsuura
# Recording 13 of 2|isangel
# Recording 14 of 2|tasiilaq
# Recording 15 of 2|clyde river
# Recording 16 of 2|hvolsvollur
# Recording 17 of 2|new norfolk
# Recording 18 of 2|mar del plata
# Recording 19 of 2|hobyo
# Recording 20 of 2|sumbawanga
# Recording 21 of 2|severo-kurilsk
# Recording 22 of 2|aktash
# Recording 23 of 2|yelizovo
# Recording 24 of 2|noumea
# Recording 25 of 2|hounde
# Recording 26 of 2|port elizabeth
# Recording 27 of 2|yarada
# Recording 28 of 2|avarua
# Recording 29 of 2|illoqqortoormiut
# City not found, skipping...
# Recording 30 of 2|zasosna
# Recording 31 of 2|mikhaylovskoye
# Recording 32 of 2|saldanha
# Recording 33 of 2|naryan-mar
# Recording 34 of 2|lasa
# Recording 35 of 2|orotukan
# Recording 36 of 2|diffa
# Recording 37 of 2|hithadhoo
# Recording 38 of 2|nikolskoye
# Recording 39 of 2|chitral
# Recording 40 of 2|urdoma
# Recording 41 of 2|nuuk
# Recording 42 of 2|tura
# Recording 43 of 2|nelson bay
# Recording 44 of 2|vyshkov
# Recording 45 of 2|axim
# Recording 46 of 2|westport
# Recording 47 of 2|gornopravdinsk
# Recording 48 of 2|lagoa
# Recording 49 of 2|vernon
# Recording 50 of 2|georgiyevskoye
# Recording 1 of 3|albany
# Recording 2 of 3|airai
# Recording 3 of 3|salaspils
# Recording 4 of 3|araceli
# Recording 5 of 3|rockland
# Recording 6 of 3|vigrestad
# Recording 7 of 3|zhigansk
# Recording 8 of 3|haines junction
# Recording 9 of 3|tuktoyaktuk
# Recording 10 of 3|nhamunda
# Recording 11 of 3|nizhneyansk
# City not found, skipping...
# Recording 12 of 3|waipawa
# Recording 13 of 3|saskylakh
# Recording 14 of 3|chikoy
# City not found, skipping...
# Recording 15 of 3|puerto madero
# Recording 16 of 3|parauna
# Recording 17 of 3|esperance
# Recording 18 of 3|tigil
# Recording 19 of 3|georgetown
# Recording 20 of 3|les cayes
# Recording 21 of 3|hrodna
# Recording 22 of 3|solovetskiy
# City not found, skipping...
# Recording 23 of 3|barrow
# Recording 24 of 3|kaitangata
# Recording 25 of 3|coos bay
# Recording 26 of 3|husavik
# Recording 27 of 3|pafos
# Recording 28 of 3|mehamn
# Recording 29 of 3|santiago de chuco
# Recording 30 of 3|butaritari
# Recording 31 of 3|yuzhno-yeniseyskiy
# City not found, skipping...
# Recording 32 of 3|tsihombe
# City not found, skipping...
# Recording 33 of 3|tres arroyos
# Recording 34 of 3|henties bay
# Recording 35 of 3|asbury park
# Recording 36 of 3|vanimo
# Recording 37 of 3|bereda
# Recording 38 of 3|namtsy
# Recording 39 of 3|bambous virieux
# Recording 40 of 3|talakan
# Recording 41 of 3|manaure
# Recording 42 of 3|belmonte
# Recording 43 of 3|svetlogorsk
# Recording 44 of 3|bargal
# City not found, skipping...
# Recording 45 of 3|karaul
# City not found, skipping...
# Recording 46 of 3|bodden town
# Recording 47 of 3|belushya guba
# City not found, skipping...
# Recording 48 of 3|vila velha
# Recording 49 of 3|grand river south east
# City not found, skipping...
# Recording 50 of 3|ust-omchug
# Recording 1 of 4|skagastrond
# City not found, skipping...
# Recording 2 of 4|ferreiras
# Recording 3 of 4|port lincoln
# Recording 4 of 4|coolum beach
# Recording 5 of 4|muravlenko
# Recording 6 of 4|chuy
# Recording 7 of 4|longyearbyen
# Recording 8 of 4|key west
# Recording 9 of 4|skibbereen
# Recording 10 of 4|makokou
# Recording 11 of 4|cheuskiny
# City not found, skipping...
# Recording 12 of 4|nagapattinam
# Recording 13 of 4|novochernorechenskiy
# Recording 14 of 4|qaqortoq
# Recording 15 of 4|fortuna
# Recording 16 of 4|saint-philippe
# Recording 17 of 4|sao filipe
# Recording 18 of 4|jalu
# Recording 19 of 4|west wendover
# Recording 20 of 4|tomatlan
# Recording 21 of 4|naze
# Recording 22 of 4|kruisfontein
# Recording 23 of 4|upernavik
# Recording 24 of 4|barahona
# Recording 25 of 4|saint anthony
# Recording 26 of 4|umm kaddadah
# Recording 27 of 4|vostok
# Recording 28 of 4|saint george
# Recording 29 of 4|yeppoon
# Recording 30 of 4|moose factory
# Recording 31 of 4|dunhua
# Recording 32 of 4|chagda
# City not found, skipping...
# Recording 33 of 4|arraial do cabo
# Recording 34 of 4|carnarvon
# Recording 35 of 4|cape town
# Recording 36 of 4|narsaq
# Recording 37 of 4|lorengau
# Recording 38 of 4|colares
# Recording 39 of 4|sao raimundo das mangabeiras
# Recording 40 of 4|muros
# Recording 41 of 4|comodoro rivadavia
# Recording 42 of 4|champerico
# Recording 43 of 4|nanortalik
# Recording 44 of 4|vaini
# Recording 45 of 4|kamyaran
# Recording 46 of 4|castro
# Recording 47 of 4|dharmanagar
# Recording 48 of 4|mantang
# Recording 49 of 4|cidreira
# Recording 50 of 4|pacific grove
# Recording 1 of 5|burns lake
# Recording 2 of 5|saleaula
# City not found, skipping...
# Recording 3 of 5|dibaya
# City not found, skipping...
# Recording 4 of 5|carballo
# Recording 5 of 5|bonfim
# Recording 6 of 5|taszar
# Recording 7 of 5|shahr-e babak
# Recording 8 of 5|kajaani
# Recording 9 of 5|beloha
# Recording 10 of 5|hasaki
# Recording 11 of 5|port macquarie
# Recording 12 of 5|san patricio
# Recording 13 of 5|salinopolis
# Recording 14 of 5|tuzha
# Recording 15 of 5|tuatapere
# Recording 16 of 5|pevek
# Recording 17 of 5|cabo san lucas
# Recording 18 of 5|salalah
# Recording 19 of 5|yerbogachen
# Recording 20 of 5|hofn
# Recording 21 of 5|huarmey
# Recording 22 of 5|samarai
# Recording 23 of 5|ban dung
# Recording 24 of 5|cozumel
# Recording 25 of 5|mackay
# Recording 26 of 5|bethel
# Recording 27 of 5|kalmunai
# Recording 28 of 5|tabou
# Recording 29 of 5|maralal
# Recording 30 of 5|acapulco
# Recording 31 of 5|kieta
# Recording 32 of 5|namibe
# Recording 33 of 5|pimentel
# Recording 34 of 5|lompoc
# Recording 35 of 5|kavieng
# Recording 36 of 5|agua verde
# Recording 37 of 5|leshukonskoye
# Recording 38 of 5|batagay-alyta
# Recording 39 of 5|vestmannaeyjar
# Recording 40 of 5|port augusta
# Recording 41 of 5|ostrovnoy
# Recording 42 of 5|samusu
# City not found, skipping...
# Recording 43 of 5|norman wells
# Recording 44 of 5|kamaishi
# Recording 45 of 5|birjand
# Recording 46 of 5|taplanszentkereszt
# Recording 47 of 5|lantawan
# Recording 48 of 5|tabas
# Recording 49 of 5|faya
# Recording 50 of 5|puerto escondido
# Recording 1 of 6|puerto baquerizo moreno
# Recording 2 of 6|aklavik
# Recording 3 of 6|aiquile
# Recording 4 of 6|provideniya
# Recording 5 of 6|tatawin
# Recording 6 of 6|bure
# Recording 7 of 6|omsukchan
# Recording 8 of 6|bandarbeyla
# Recording 9 of 6|khatanga
# Recording 10 of 6|cefa
# Recording 11 of 6|cayenne
# Recording 12 of 6|medvedok
# Recording 13 of 6|laizhou
# Recording 14 of 6|turinsk
# Recording 15 of 6|laguna
# Recording 16 of 6|shelburne
# Recording 17 of 6|yulara
# Recording 18 of 6|tarko-sale
# Recording 19 of 6|atambua
# Recording 20 of 6|juegang
# Recording 21 of 6|egvekinot
# Recording 22 of 6|tual
# Recording 23 of 6|numan
# Recording 24 of 6|botevgrad
# Recording 25 of 6|karamea
# City not found, skipping...
# Recording 26 of 6|bemidji
# Recording 27 of 6|myitkyina
# Recording 28 of 6|doha
# Recording 29 of 6|tooele
# Recording 30 of 6|suriapet
# Recording 31 of 6|aksay
# Recording 32 of 6|teknaf
# Recording 33 of 6|sitka
# Recording 34 of 6|malanje
# Recording 35 of 6|leningradskiy
# Recording 36 of 6|north branch
# Recording 37 of 6|nabire
# Recording 38 of 6|surt
# Recording 39 of 6|rio gallegos
# Recording 40 of 6|knysna
# Recording 41 of 6|skovde
# City not found, skipping...
# Recording 42 of 6|komatipoort
# Recording 43 of 6|dingle
# Recording 44 of 6|coihaique
# Recording 45 of 6|sharan
# Recording 46 of 6|mogadishu
# Recording 47 of 6|kumluca
# Recording 48 of 6|mirnyy
# Recording 49 of 6|faanui
# Recording 50 of 6|fierze
# City not found, skipping...
# Recording 1 of 7|caravelas
# Recording 2 of 7|ilulissat
# Recording 3 of 7|agnibilekrou
# Recording 4 of 7|portland
# Recording 5 of 7|mitu
# Recording 6 of 7|gambela
# Recording 7 of 7|dombarovskiy
# Recording 8 of 7|urdzhar
# City not found, skipping...
# Recording 9 of 7|cumberland
# Recording 10 of 7|ballina
# Recording 11 of 7|kamenskoye
# City not found, skipping...
# Recording 12 of 7|victor harbor
# Recording 13 of 7|ponta do sol
# Recording 14 of 7|maragogi
# Recording 15 of 7|nome
# Recording 16 of 7|dikson
# Recording 17 of 7|sadu
# Recording 18 of 7|teya
# Recording 19 of 7|iqaluit
# Recording 20 of 7|atasu
# Recording 21 of 7|yangambi
# Recording 22 of 7|paamiut
# Recording 23 of 7|klaksvik
# Recording 24 of 7|zelenoborskiy
# Recording 25 of 7|port hedland
# Recording 26 of 7|adrar
# Recording 27 of 7|kahului
# Recording 28 of 7|te anau
# Recording 29 of 7|daigo
# Recording 30 of 7|omachi
# Recording 31 of 7|devonport
# Recording 32 of 7|kargasok
# Recording 33 of 7|khandyga
# Recording 34 of 7|cody
# Recording 35 of 7|tiznit
# Recording 36 of 7|toamasina
# Recording 37 of 7|roald
# Recording 38 of 7|manadhoo
# Recording 39 of 7|baruun-urt
# Recording 40 of 7|mount gambier
# Recording 41 of 7|dicabisagan
# Recording 42 of 7|kasongo-lunda
# Recording 43 of 7|dolores
# Recording 44 of 7|tomohon
# Recording 45 of 7|montana
# Recording 46 of 7|miraflores
# Recording 47 of 7|sokol
# Recording 48 of 7|kyren
# Recording 49 of 7|carnot
# Recording 50 of 7|port hawkesbury
# Recording 1 of 8|kulhudhuffushi
# Recording 2 of 8|vaitupu
# City not found, skipping...
# Recording 3 of 8|mahebourg
# Recording 4 of 8|morondava
# Recording 5 of 8|grindavik
# Recording 6 of 8|tirumullaivasal
# Recording 7 of 8|sur
# Recording 8 of 8|bageshwar
# Recording 9 of 8|oranjemund
# Recording 10 of 8|ulladulla
# Recording 11 of 8|poum
# Recording 12 of 8|proletarsk
# Recording 13 of 8|zambezi
# Recording 14 of 8|nizwa
# Recording 15 of 8|talaya
# Recording 16 of 8|cockburn town
# Recording 17 of 8|luderitz
# Recording 18 of 8|ginir
# Recording 19 of 8|lebu
# Recording 20 of 8|isabela
# Recording 21 of 8|bathsheba
# Recording 22 of 8|barra do bugres
# Recording 23 of 8|bo rai
# Recording 24 of 8|naftah
# City not found, skipping...
# Recording 25 of 8|invercargill
# Recording 26 of 8|port-cartier
# Recording 27 of 8|sao jose da coroa grande
# Recording 28 of 8|palmito
# Recording 29 of 8|villafranca de los barros
# Recording 30 of 8|fereydun kenar
# Recording 31 of 8|san quintin
# Recording 32 of 8|bintulu
# Recording 33 of 8|rockport
# Recording 34 of 8|sanmenxia
# Recording 35 of 8|petauke
# Recording 36 of 8|katima mulilo
# Recording 37 of 8|camrose
# Recording 38 of 8|ponnani
# Recording 39 of 8|lata
# Recording 40 of 8|uyuni
# Recording 41 of 8|marcona
# City not found, skipping...
# Recording 42 of 8|miro khan
# Recording 43 of 8|iwanai
# Recording 44 of 8|olga
# Recording 45 of 8|rudersdorf
# Recording 46 of 8|vardo
# Recording 47 of 8|zuwarah
# Recording 48 of 8|baiquan
# Recording 49 of 8|prince rupert
# Recording 50 of 8|chumikan
# Recording 1 of 9|ialibu
# Recording 2 of 9|san angelo
# Recording 3 of 9|tumannyy
# City not found, skipping...
# Recording 4 of 9|blagoyevo
# Recording 5 of 9|whitehorse
# Recording 6 of 9|barbar
# City not found, skipping...
# Recording 7 of 9|la ronge
# Recording 8 of 9|clarksburg
# Recording 9 of 9|bonavista
# Recording 10 of 9|ahipara
# Recording 11 of 9|weatherford
# Recording 12 of 9|tufeni
# Recording 13 of 9|kenai
# Recording 14 of 9|havre-saint-pierre
# Recording 15 of 9|snasa
# Recording 16 of 9|general roca
# Recording 17 of 9|luganville
# Recording 18 of 9|angoche
# Recording 19 of 9|almaznyy
# Recording 20 of 9|polson
# Recording 21 of 9|luwingu
# Recording 22 of 9|barcelos
# Recording 23 of 9|bartica
# Recording 24 of 9|rio grande
# Recording 25 of 9|la crosse
# Recording 26 of 9|high level
# Recording 27 of 9|muzhi
# Recording 28 of 9|scottsburgh
# City not found, skipping...
# Recording 29 of 9|tiarei
# Recording 30 of 9|mys shmidta
# City not found, skipping...
# Recording 31 of 9|whitecourt
# Recording 32 of 9|cap-aux-meules
# Recording 33 of 9|waingapu
# Recording 34 of 9|nueva guinea
# Recording 35 of 9|xique-xique
# Recording 36 of 9|malwan
# City not found, skipping...
# Recording 37 of 9|grand forks
# Recording 38 of 9|itarema
# Recording 39 of 9|marawi
# Recording 40 of 9|vung tau
# Recording 41 of 9|derzhavinsk
# Recording 42 of 9|buritizeiro
# Recording 43 of 9|mutum
# Recording 44 of 9|rostovka
# Recording 45 of 9|taoudenni
# Recording 46 of 9|vaasa
# Recording 47 of 9|neuquen
# Recording 48 of 9|haibowan
# City not found, skipping...
# Recording 49 of 9|punta alta
# Recording 50 of 9|port blair
# Recording 1 of 10|coahuayana
# Recording 2 of 10|guilin
# Recording 3 of 10|katangli
# Recording 4 of 10|trelew
# Recording 5 of 10|najran
# Recording 6 of 10|covasna
# Recording 7 of 10|abha
# Recording 8 of 10|inskoy
# Recording 9 of 10|malchevskaya
# Recording 10 of 10|viedma
# Recording 11 of 10|san cristobal
# Recording 12 of 10|ridgecrest
# Recording 13 of 10|opuwo
# Recording 14 of 10|jining
# Recording 15 of 10|porbandar
# Recording 16 of 10|port-gentil
# Recording 17 of 10|grand gaube
# Recording 18 of 10|zolotkovo
# Recording 19 of 10|manuk mangkaw
# Recording 20 of 10|pisco
# Recording 21 of 10|aswan
# Recording 22 of 10|zhangjiakou
# Recording 23 of 10|geraldton
# Recording 24 of 10|srednekolymsk
# Recording 25 of 10|beringovskiy
# Recording 26 of 10|bulgan
# Recording 27 of 10|souillac
# Recording 28 of 10|nalut
# Recording 29 of 10|yegorlykskaya
# Recording 30 of 10|road town
# Recording 31 of 10|solnechnyy
# Recording 32 of 10|kuytun
# Recording 33 of 10|hovd
# Recording 34 of 10|ocos
# Recording 35 of 10|dmitriyevka
# Recording 36 of 10|ushtobe
# Recording 37 of 10|cacoal
# Recording 38 of 10|hualmay
# Recording 39 of 10|contai
# Recording 40 of 10|santiago del estero
# Recording 41 of 10|udimskiy
# Recording 42 of 10|olinda
# Recording 43 of 10|port hardy
# Recording 44 of 10|yurginskoye
# Recording 45 of 10|kattivakkam
# Recording 46 of 10|jiancheng
# Recording 47 of 10|chakulia
# Recording 48 of 10|karkaralinsk
# City not found, skipping...
# Recording 49 of 10|sao paulo de olivenca
# Recording 50 of 10|casablanca
# Recording 1 of 11|altar
# Recording 2 of 11|isiro
# Recording 3 of 11|sola
# Recording 4 of 11|hornepayne
# Recording 5 of 11|alekseyevsk
# Recording 6 of 11|kloulklubed
# Recording 7 of 11|pitea
# Recording 8 of 11|saint-georges
# Recording 9 of 11|cabedelo
# Recording 10 of 11|mantua
# Recording 11 of 11|karratha
# Recording 12 of 11|maxixe
# Recording 13 of 11|erechim
# Recording 14 of 11|tungkang
# City not found, skipping...
# Recording 15 of 11|codrington
# Recording 16 of 11|marsh harbour
# Recording 17 of 11|mnogovershinnyy
# Recording 18 of 11|padang
# Recording 19 of 11|amapa
# Recording 20 of 11|tabuk
# Recording 21 of 11|ixtapa
# Recording 22 of 11|buldana
# Recording 23 of 11|linares
# Recording 24 of 11|marystown
# Recording 25 of 11|kuopio
# Recording 26 of 11|luanda
# Recording 27 of 11|juneau
# Recording 28 of 11|samfya
# Recording 29 of 11|bosaso
# Recording 30 of 11|bilma
# Recording 31 of 11|kavaratti
# Recording 32 of 11|yumen
# Recording 33 of 11|jahrom
# City not found, skipping...
# Recording 34 of 11|umm lajj
# Recording 35 of 11|nouadhibou
# Recording 36 of 11|labutta
# City not found, skipping...
# Recording 37 of 11|sinnamary
# Recording 38 of 11|itinga
# Recording 39 of 11|sayyan
# Recording 40 of 11|algiers
# Recording 41 of 11|chalmette
# Recording 42 of 11|eureka
# Recording 43 of 11|anadyr
# Recording 44 of 11|gwadar
# Recording 45 of 11|malindi
# Recording 46 of 11|hihifo
# City not found, skipping...
# Recording 47 of 11|los llanos de aridane
# Recording 48 of 11|amga
# Recording 49 of 11|miranorte
# City not found, skipping...
# Recording 50 of 11|joensuu
# Recording 1 of 12|touros
# Recording 2 of 12|myanaung
# Recording 3 of 12|leh
# Recording 4 of 12|manokwari
# Recording 5 of 12|severodvinsk
# Recording 6 of 12|pendleton
# Recording 7 of 12|kendari
# Recording 8 of 12|shenjiamen
# Recording 9 of 12|kralendijk
# Recording 10 of 12|palabuhanratu
# City not found, skipping...
# Recording 11 of 12|kemi
# Recording 12 of 12|manta
# Recording 13 of 12|wolomin
# Recording 14 of 12|wejherowo
# Recording 15 of 12|boa vista
# Recording 16 of 12|calintaan
# Recording 17 of 12|kutiyana
# Recording 18 of 12|korla
# Recording 19 of 12|kaura namoda
# Recording 20 of 12|wattegama
# Recording 21 of 12|sioux lookout
# Recording 22 of 12|pak phanang
# Recording 23 of 12|esfahan
# Recording 24 of 12|semnan
# Recording 25 of 12|miandrivazo
# Recording 26 of 12|kazalinsk
# City not found, skipping...
# Recording 27 of 12|tilichiki
# Recording 28 of 12|weinan
# Recording 29 of 12|bolu
# Recording 30 of 12|byurakan
# Recording 31 of 12|mahuva
# Recording 32 of 12|kjopsvik
# Recording 33 of 12|dryden
# Recording 34 of 12|mocajuba
# Recording 35 of 12|tezu
# Recording 36 of 12|salinas
# Recording 37 of 12|dickinson
# Recording 38 of 12|sao sepe
# Recording 39 of 12|oyo
# Recording 40 of 12|nishihara
# Recording 41 of 12|galiwinku
# City not found, skipping...
# Recording 42 of 12|orange cove
# Recording 43 of 12|sakaiminato
# Recording 44 of 12|santa maria
# Recording 45 of 12|kiama
# Recording 46 of 12|san vicente
# Recording 47 of 12|kanniyakumari
# Recording 48 of 12|valdivia
# Recording 49 of 12|tatarsk
# Recording 50 of 12|seoul
# Recording 1 of 13|yar-sale
# Recording 2 of 13|manastirea casin
# City not found, skipping...
# Recording 3 of 13|lavrentiya
# Recording 4 of 13|nogent-le-rotrou
# Recording 5 of 13|kamenka
# Recording 6 of 13|darhan
# Recording 7 of 13|mangrol
# Recording 8 of 13|chilca
# Recording 9 of 13|sao felix do xingu
# Recording 10 of 13|phan rang
# City not found, skipping...
# Recording 11 of 13|hirara
# Recording 12 of 13|zlatoustovsk
# City not found, skipping...
# Recording 13 of 13|flinders
# Recording 14 of 13|whithorn
# Recording 15 of 13|sesheke
# Recording 16 of 13|galesong
# Recording 17 of 13|igarka
# ----------------------------
# Data Retrieval Complete
# ----------------------------
# 567

# %%
# store results as a dataframe
city_data_df = pd.DataFrame(city_data)

# Save the data frame to a csv file
city_data_df.to_csv('data\WeatherPy_database.csv', index_label='City ID')

# %%
# Find the cities where it is raining
raining_cities = city_data_df.loc[city_data_df['Rain (inches)'] > 0]
len(raining_cities)

# Find the cities where it is snowing
snowing_cities = city_data_df.loc[city_data_df['Snow (inches)'] > 0]
len(snowing_cities)
# Out:
# 0
